# %% [markdown]
# # FinAI Research
# Lean QuantBook research environment. Run cells top to bottom.

# %%
# %run start.py
qb = QuantBook()
print('QuantBook ready')

# %%
from datetime import datetime
spy = qb.add_equity('SPY', Resolution.DAILY)
hist = qb.history(spy.symbol, datetime(2013,10,1), datetime(2013,10,31), Resolution.DAILY)
hist[['open','high','low','close','volume']].head()

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
closes = hist['close'].reset_index(level=0, drop=True)
ax = closes.plot(figsize=(10,4), title='SPY daily close')
print('rows plotted:', len(closes))
